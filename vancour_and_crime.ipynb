# %%
install.packages("VancouvR")
install.packages("geojsonio")
# Out:
# Installing package into 'C:/Users/Kaiyan Zhang/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
library(geojsonio)
library(tidyverse)
library(dplyr)
# Out:
# Registered S3 method overwritten by 'geojsonsf':
#   method        from
#   print.geojson geojson
#
#
# Attaching package: 'geojsonio'
#
#
# The following object is masked from 'package:base':
#
#     pretty
#
#
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.4     v readr     2.1.5
# v forcats   1.0.0     v stringr   1.5.0
# v ggplot2   3.5.1     v tibble    3.2.1
# v lubridate 1.9.3     v tidyr     1.3.1
# v purrr     1.0.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
library(VancouvR)

list_cov_datasets()
# Out:
#     dataset_id
# 1   2023-2026-capital-plan-and-2024-capital-budget-with-proposed-four-year-capital-0
# 2   2024-multi-year-capital-project-budget-requests-and-capital-expenditure-budget
# 3   voting-places-2022
# 4   indicator-details
# 5   storefronts-inventory
# 6   false-creek-navigable-channel
# 7   3-1-1-inquiry-volume
# 8   city-boundary
# 9   3-1-1-service-requests-2009-2021
# 10  2023-multi-year-capital-project-budget-requests-and-capital-expenditure-budget
# 11  drinking-fountains
# 12  2023-2026-capital-plan-and-2023-capital-budget-with-proposed-four-year-capital-p
# 13  city-project-package-street
# 14  facet-grid-boundaries
# 15  building-footprints-2009
# 16  elected-officials-contact-information
# 17  free-and-low-cost-food-programs
# 18  operating-permits-water-systems-water-quality-reports
# 19  cultural-spaces
# 20  building-lines
# 21  animal-control-inventory-deceased-animal
# 22  awarded-contracts
# 23  elevation-contour-lines-1-metre-contours
# 24  homeless-shelter-locations
# 25  district-lot-outlines
# 26  fire-halls
# 27  district-lot-numbers
# 28  goads-fire-insurance-map-1912-georectified
# 29  development-cost-levy-dcl-areas
# 30  downtown-historic-railway
# ... ...
# 160 open-data-change-log
# 161 parks
# 162 parking-meters
# 163 water-transmission-mains
# 164 street-lighting-abandoned-conduits
# 165 animal-control-inventory-lost-and-found
# 166 employee-remuneration-and-expenses-earning-over-75000
# 167 sewer-catch-basins
# 168 public-washrooms
# 169 property-cadastral-boundaries
# 170 business-licences
# 171 traffic-signals
# 172 issued-operating-permits-water-systems-
# 173 local-area-boundary
# 174 one-way-streets
# 175 property-addresses
# 176 web-cam-url-links
# 177 city-owned-properties
# 178 3-1-1-service-requests
# 179 parks-facilities
# 180 lidar-2022
# 181 road-ahead-projects-under-construction
# 182 disability-parking
# 183 street-trees
# 184 orthophoto-imagery-2022
# 185 public-art
# 186 shoreline-2002
# 187 workforce-pay-rates-and-gender
# 188 block-numbers
# 189 property-tax-report
#     title
# 1   2023-2026 Capital Plan and 2024 Capital Budget with proposed four-year Capital Plan allocations
# 2   2024 Multi-Year Capital Project Budget requests and Capital Expenditure Budget
# 3   Voting places 2022
# 4   Indicator Details
# 5   Storefronts Inventory
# 6   False Creek navigable channel
# 7   3-1-1 inquiry volume
# 8   City boundary
# 9   3-1-1 service requests 2009-2021
# 10  2023 Multi-Year Capital Project Budget requests and Capital Expenditure Budget
# 11  Drinking fountains
# 12  2023-2026 Capital Plan and 2023 Capital Budget with proposed four-year Capital Plan allocations
# 13  City project package - Street
# 14  Facet grid boundaries
# 15  Building footprints 2009
# 16  Elected officials contact information
# 17  Free and low cost food programs
# 18  Operating permits - water systems — water quality reports
# 19  Cultural Spaces
# 20  Building lines
# 21  Animal control inventory - deceased animal
# 22  Awarded contracts
# 23  Elevation contour lines - 1-metre contours
# 24  Homeless shelter locations
# 25  District lot outlines
# 26  Fire halls
# 27  District lot numbers
# 28  Goad's Fire Insurance Map 1912 (georectified)
# 29  Development Cost Levy (DCL) areas
# 30  Downtown Historic Railway
# ... ...
# 160 Open data change log
# 161 Parks
# 162 Parking meters
# 163 Water transmission mains
# 164 Street lighting abandoned conduits
# 165 Animal control inventory - lost and found
# 166 Employee remuneration and expenses (earning over $75,000)
# 167 Sewer catch basins
# 168 Public washrooms
# 169 Property cadastral boundaries
# 170 Business licences
# 171 Traffic signals
# 172 Issued operating permits – water systems
# 173 Local area boundary
# 174 One way streets
# 175 Property addresses
# 176 Web Cam (URL links)
# 177 City-owned properties
# 178 3-1-1 service requests
# 179 Parks facilities
# 180 LiDAR 2022
# 181 Road Ahead projects under construction
# 182 Disability parking
# 183 Street trees
# 184 Orthophoto imagery 2022
# 185 Public art
# 186 Shoreline 2002
# 187 Workforce pay rates and sex
# 188 Block numbers
# 189 Property tax report
#     keyword
# 1   budget
# 2   budget
# 3   election
# 4   dashboard
# 5   NA
# 6   traffic
# 7   NA
# 8   NA
# 9   NA
# 10  budget
# 11  water
# 12  budget
# 13  city project
# 14  NA
# 15  building
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  property
# 21  animal control
# 22  NA
# 23  NA
# 24  NA
# 25  property
# 26  NA
# 27  property
# 28  NA
# 29  NA
# 30  traffic
# ... ...
# 160 NA
# 161 park
# 162 parking,traffic
# 163 water
# 164 street lighting
# 165 animal control
# 166 NA
# 167 sewer
# 168 toilet
# 169 property
# 170 licence
# 171 traffic
# 172 NA
# 173 NA
# 174 street
# 175 property
# 176 NA
# 177 property
# 178 NA
# 179 park
# 180 NA
# 181 traffic
# 182 parking,traffic
# 183 NA
# 184 NA
# 185 art
# 186 NA
# 187 NA
# 188 property
# 189 NA
#     search-term
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   anchor
# 7   311, 3-1-1, contact centre, call, centre, center, volume, inquiry
# 8   legal, jurisdiction
# 9   311, 3-1-1, contact centre, call, center, volume, service request, case
# 10  NA
# 11  water, public, parks and recreation, engineering services, bottle filling, bottle
# 12  NA
# 13  development, construction, roadwork
# 14  boundary, map
# 15  NA
# 16  council, mayor, councillor, commissioner, election
# 17  NA
# 18  NA
# 19  facilities, arts and culture
# 20  NA
# 21  deceased, lost and found, register
# 22  Purchasing, bid, supplier, supply
# 23  NA
# 24  homelessness
# 25  address label, block number, block outline, cadastral boundaries, building lines, district lot, number, legal lot number, graffiti, heritage site, property address, easement, parcel polygon, tie line, property boundary, package
# 26  station
# 27  address label, block number, block outline, cadastral boundaries, building lines, \nlegal lot number, graffiti, heritage site, property address, easement, parcel polygon, tie line, property boundary, package
# 28  map, historical
# 29  NA
# 30  NA
# ... ...
# 160 changelog, history
# 161 NA
# 162 rate
# 163 NA
# 164 NA
# 165 deceased animals, register
# 166 salary, salaries, staff, discretionary
# 167 NA
# 168 toilet, restroom, comfort station, automated public toilet, APT, park
# 169 address label, block number, block outline, building lines, district lot, number, legal lot number, graffiti, heritage site, property address, easement, parcel polygon, tie line, property boundary, package
# 170 licence, permit, license
# 171 light
# 172 NA
# 173 neighbourhood. local planning area, boundaries, neighborhood
# 174 NA
# 175 address label, block number, block outline, cadastral boundaries, building lines, district lot, number, legal lot number, graffiti, heritage site, easement, parcel polygon, tie line, property boundary, package
# 176 traffic, camera, location, image, intersection
# 177 owned, property, real estate, facilities management
# 178 311, 3-1-1, contact centre, call, center, volume, service request, case
# 179 NA
# 180 digital elevation model, degree, vector, remote sensing elevation, aerial, mapping
# 181 NA
# 182 Disabled, disability, accessible, meter, metre
# 183 tree canopy
# 184 orthophoto, imagery, aerial, photography
# 185 NA
# 186 shore, 2002
# 187 employee, remuneration, staff, salary, equity
# 188 address label, block outline, cadastral boundaries, building lines, district lot, number, legal lot number, graffiti, heritage site, property address, easement, parcel polygon, tie line, property boundary, package
# 189 house
#     description
# 1   <p>This dataset includes the details of 2023-2026 Capital Plan – original plan, updates, funding sources and planned allocations over 2023-2026. This dataset also links new 2024 Capital Project Budget requests to the previously approved multi-year Capital Project Budgets from prior Capital Plans.</p><h3>Data currency</h3><p>The dataset o<U+200B>n this website reflects information about the original 2023-2026 Capital Plan, updates to the same as part of 2024 Capital Budget, proposed updates to the same as part of 2024 Capital Budget, proposed 4 year allocations of the Capital Plan and 2023 new multi-year Capital Project Budget requests. Council has approved the 2023 Capital Budget in December 2023, following which, further changes can be expected based on Council direction.<br></p><p>The Multi-Year Capital Budget evolves over time through the continuous capital budget processes to update the capital plan and capital budgets including quarterly capital budget adjustments and stand-alone council reporting.<br></p><h3>Data accuracy</h3><div><p><U+200B>There are no known errors but there may be some loss of quality from data entry errors.<br></p></div><h3>Websites for further information</h3><div><p><U+200B><a href="https://vancouver.ca/your-government/annual-budget.aspx" target="_blank">2024 Budget<U+200B></a><br></p></div>
# 2   <p class="">This dataset includes the new 2024 Capital Project Budget requests from the 2023-2026 Capital Plan (broken down by funding sources), forecast spending of previously approved multi-year capital project budgets through 2023, and forecasted expenditures over 2024-2028 from the available project budget in 2024. The available project budget includes the new 2024 Capital Project Budget requests from the 2024-2028 Capital Plan and unspent budget from the previously approved multi-year capital project budgets from prior Capital Plans.</p><h3 class="">Data Currency</h3><p class="">The dataset on this website reflects information about the new 2024 Capital Project Budget requests, 2024 Capital Expenditure Budget and forecasted capital project expenditures over 2024-2028. It is planned to be submitted for Council approval in December 2023, following which, further changes can be expected based on Council direction.</p><p class="">The Multi-Year Capital Project Budgets and the Capital Expenditure Budget evolve over time through the continuous capital budget processes to update the capital plan and capital budgets including quarterly capital budget adjustments and stand-alone council reporting. </p><h3 class="">Data accuracy</h3><p class="">There are no known errors but there may be some loss of quality from data entry errors.</p><h3 class="">Websites for further information</h3><p class=""><a href="https://vancouver.ca/your-government/annual-budget.aspx" target="_blank">2024 Budget</a></p>
# 3   <div><p>This dataset includes all of the voting places available to voters for the 2022 general election. The City of Vancouver uses a Vote-Anywhere model.<U+200B><U+200B> Since 2014, voters can vote at any voting place within the City.<U+200B><U+200B><br/></p><p><U+200B>The City operates an at-large <U+200B><U+200B>voting system.<U+200B><U+200B><br/></p><p><U+200B><U+200B><U+200B><U+200B>Advance voting days: Octobe<U+200B><U+200B>r 1, 5, 8, 11, 13<U+200B><U+200B><U+200B></p><p><U+200B><U+200B>Election day: October 15<U+200B><U+200B></p><p><U+200B><U+200B><U+200B><U+200B><U+200B><U+200B><U+200B>Voting hours for all locations are 8am to 8pm.<br/></p><p>\n      <strong>Note:</strong></p><p><U+200B>UBC <U+200B>and UEL residents are only eligible to vote for School trustees.</p></div>  <h3>Data currency</h3><div><p><U+200B><U+200B>These are the voting places used for the <U+200B>City's 2022 municipal general election during advance voting and on general voting day.<U+200B><U+200B><br/></p></div>  <h3>Websites for further information</h3><div><ul><li> \n      <a href="https://vancouver.ca/your-government/civic-elections.aspx">Municipal elections<U+200B></a><U+200B><br/></li></ul></div>
# 4   Data in this dataset drive indicator detail pages accessible from dashboards. For a user-friendly view of this data please explore our dashboards <a href="https://opendata.vancouver.ca/pages/dashboards">landing page</a>.
# ...
# 16  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=elected-officials-contact-information
# 17  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=free-and-low-cost-food-programs
# 18  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=operating-permits-water-systems-%e2%80%94-water-quality-reports
# 19  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=cultural-spaces
# 20  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=building-lines
# 21  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=animal-control-inventory-deceased-animal
# 22  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=awarded-contracts
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=goads-fire-insurance-map-1912-georectified
# 29  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=development-cost-levy-dcl-areas
# 30  https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=downtown-historic-railway
# ... ...
# 160 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=open-data-change-log
# 161 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=parks
# 162 NA
# 163 NA
# 164 NA
# 165 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=animal-control-inventory-lost-and-found
# 166 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=employee-remuneration-and-expenses-earning-over-75000
# 167 NA
# 168 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=public-washrooms
# 169 NA
# 170 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=business-licences
# 171 NA
# 172 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=issued-operating-permits-%e2%80%93-water-systems-
# 173 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=local-area-boundary
# 174 NA
# 175 NA
# 176 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=web-cam-url-links
# 177 NA
# 178 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=3-1-1-service-requests
# 179 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=parks-facilities
# 180 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=lidar-2022
# 181 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=road-ahead-projects-under-construction
# 182 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=disability-parking
# 183 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=street-trees
# 184 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=orthophoto-imagery-2022
# 185 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=public-art
# 186 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=shoreline-2002
# 187 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=workforce-pay-rates-and-gender
# 188 NA
# 189 https://opendata.vancouver.ca/explore/dataset/open-data-change-log/log/?disjunctive.datasets&amp;sort=logdate&amp;refine.datasetids=property-tax-report
#     datasetid
# 1   2023-2026-capital-plan-and-2024-capital-budget-with-proposed-four-year-capital-0
# 2   2024-multi-year-capital-project-budget-requests-and-capital-expenditure-budget
# 3   voting-places-2022
# 4   indicator-details
# 5   storefronts-inventory
# 6   false-creek-navigable-channel
# 7   3-1-1-inquiry-volume
# 8   city-boundary
# 9   3-1-1-service-requests-2009-2021
# 10  2023-multi-year-capital-project-budget-requests-and-capital-expenditure-budget
# 11  drinking-fountains
# 12  2023-2026-capital-plan-and-2023-capital-budget-with-proposed-four-year-capital-p
# 13  city-project-package-street
# 14  facet-grid-boundaries
# 15  building-footprints-2009
# 16  elected-officials-contact-information
# 17  free-and-low-cost-food-programs
# 18  operating-permits-water-systems-water-quality-reports
# 19  cultural-spaces
# 20  building-lines
# 21  animal-control-inventory-deceased-animal
# 22  awarded-contracts
# 23  elevation-contour-lines-1-metre-contours
# 24  homeless-shelter-locations
# 25  district-lot-outlines
# 26  fire-halls
# 27  district-lot-numbers
# 28  goads-fire-insurance-map-1912-georectified
# 29  development-cost-levy-dcl-areas
# 30  downtown-historic-railway
# ... ...
# 160 open-data-change-log
# 161 parks
# 162 parking-meters
# 163 water-transmission-mains
# 164 street-lighting-abandoned-conduits
# 165 animal-control-inventory-lost-and-found
# 166 employee-remuneration-and-expenses-earning-over-75000
# 167 sewer-catch-basins
# 168 public-washrooms
# 169 property-cadastral-boundaries
# 170 business-licences
# 171 traffic-signals
# 172 issued-operating-permits-water-systems-
# 173 local-area-boundary
# 174 one-way-streets
# 175 property-addresses
# 176 web-cam-url-links
# 177 city-owned-properties
# 178 3-1-1-service-requests
# 179 parks-facilities
# 180 lidar-2022
# 181 road-ahead-projects-under-construction
# 182 disability-parking
# 183 street-trees
# 184 orthophoto-imagery-2022
# 185 public-art
# 186 shoreline-2002
# 187 workforce-pay-rates-and-gender
# 188 block-numbers
# 189 property-tax-report

# %%
property_address <- get_cov_data("property-addresses")
# Out:
# Downloading data from CoV Open Data portal

# %%
property_address <- as.tibble(property_address)
head(property_address)

# %%
distinct(property_address, geo_local_area)

# %%
crime_data <- read_csv("econ326\crimedata_csv_AllNeighbourhoods_AllYears\crimedata_csv_AllNeighbourhoods_AllYears.csv")

# %%
distinct(crime_data, TYPE)

# %%
crime_data_selected <- crime_data|>
    filter(TYPE == c("Vehicle Collision or Pedestrian Struck (with Fatality)",
    "Vehicle Collision or Pedestrian Struck (with Injury)",
    "Break and Enter Commercial",
    "Break and Enter Residential/Other",
    "Homicide"))|>
    select(TYPE, YEAR, NEIGHBOURHOOD)

glimpse(crime_data_selected)

# %%
crime_data_selected <- crime_data_selected|>
    group_by(TYPE)|>
    arrange(YEAR)|>
    rename(type = TYPE, year = YEAR, neighbourhood = NEIGHBOURHOOD)

head(crime_data_selected)

# %%
web_cam <- get_cov_data("web-cam-url-links")

head(as_tibble(web_cam))

# %%
public_washroom <- get_cov_data("public-washrooms")|>
    as_tibble()

head(public_washroom)

# %%
public_property <- get_cov_data("city-owned-properties")|>
    as_tibble()

colnames(public_property)

# %%
head(public_property)

# %%
distinct(public_property, type)

# %%
public_property_select <- public_property|>
    filter(type == "Vancouver Public Housing Corp")|>
    select(geo_local_area, type)

head(public_property_select)

# %%
distinct(public_property_select, geo_local_area)

# %%
search_cov_datasets("transit")

# %%
rapid_transit_station <- get_cov_data("rapid-transit-stations")|>
    as_tibble()

head(rapid_transit_station)

# %%
distinct(rapid_transit_station, geo_local_area)

# %%
search_cov_datasets("culture")
